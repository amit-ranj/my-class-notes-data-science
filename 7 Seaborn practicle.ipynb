# %%
import pandas as pd

# %%
movies = pd.read_csv(r'D:\My data science career\python\class 29 march 28\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
# clean the attribute
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillion','Year']

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion         Year
# count    559.000000      559.000000     559.000000   559.000000
# mean      47.309481       58.744186      50.236136  2009.152057
# std       26.413091       16.826887      48.731817     1.362632
# min        0.000000        0.000000       0.000000  2007.000000
# 25%       25.000000       47.000000      20.000000  2008.000000
# 50%       46.000000       58.000000      35.000000  2009.000000
# 75%       70.000000       72.000000      65.000000  2010.000000
# max       97.000000       96.000000     300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies['Film'] = movies['Film'].astype('category')
movies['Genre'] = movies['Genre'].astype('category')
movies['Year'] = movies['Year'].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# converted year to category hence no year in describe
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %%
from matplotlib import pyplot as plt # visualization
import seaborn as sns # advance visualization
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = plt.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')
# jointplot attribute is not available in matplotlib.pyplot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 j = plt.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'jointplot'

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')
# Draw a plot of two variables with bivariate and univariate graphs.
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'hex')
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'kde')
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'reg')
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'scatter')
plt.show()

# %% [markdown]
# insight - from this graph we come to know that audience prefer watching movies with better audience ratings not criticratings

# %%
n1 = sns.distplot(movies.AudienceRating, color = 'Blue')
plt.show()

# %%
n1 = sns.distplot(movies.CriticRating)
plt.show()

# %%
n1 = sns.displot(movies.AudienceRating)
plt.show()

# %%
n1 = sns.displot(movies.CriticRating)
plt.show()

# %%
sns.set_style('darkgrid')
# to show the grid lines at the back of graph

# %% [markdown]
# various styles :-
# style : dict, or one of {darkgrid, whitegrid, dark, white, ticks}

# %%
n1 = sns.displot(movies.AudienceRating, bins = 10)
plt.show()

# %%
sns.set_style('white')

# %%
n1 = sns.displot(movies.AudienceRating, bins = 10)
plt.show()

# %%
sns.set_style('dark')
# have dark background
n1 = sns.displot(movies.AudienceRating, bins = 10)
plt.show()

# %%
sns.set_style('ticks')
n1 = sns.displot(movies.AudienceRating, bins = 10)
plt.show()

# %%
sns.set_style('white')
n1 = sns.displot(movies.AudienceRating, bins = 10)
plt.show()

# %%
n1 = plt.hist(movies.BudgetMillion)
plt.show()

# %%
vis1 = sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating', fit_reg = True)
plt.show()

# %%
vis1 = sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating', fit_reg = False, hue = 'Genre')
plt.show()

# %%
vis1 = sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating', fit_reg = True, hue = 'Genre')
plt.show()

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
w = sns.boxplot(data = movies, x = 'Genre', y = 'CriticRating')
plt.show()

# %%
w = sns.violinplot(data = movies, x = 'Genre', y = 'CriticRating')
plt.show()

# %%
w = sns.boxplot(data = movies[movies.Genre == 'Drama'], x = 'Year', y = 'AudienceRating')
# graph only for drama
plt.show()

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
plt.show()

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')
plt.show()

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillion')
plt.show()

# %%
#
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws ) #scatterplots are mapped in facetgrid
plt.show()

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillion,movies.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating,cmap='Reds',ax = axes[1,1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 7
#       4 sns.set_style('darkgrid')
#       5 f, axes = plt.subplots (2,2, figsize = (15,15))
# ----> 7 k1 = sns.kdeplot(movies.BudgetMillion,movies.AudienceRating,ax=axes[0,0])
#       8 k2 = sns.kdeplot(movies.BudgetMillion,movies.CriticRating,ax = axes[0,1])
#      10 k1.set(xlim=(-20,160))
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(movies.BudgetMillion,movies.AudienceRating, \
                 shade = True, shade_lowest=True,cmp = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(movies.BudgetMillion,movies.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(movies.BudgetMillion,movies.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRating, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
